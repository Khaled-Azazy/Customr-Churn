# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set_style('whitegrid')

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn - WA_Fn-UseC_-Telco-Customer-Churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
len(df[df['Churn']=='Yes'])
# Out:
# 1869

# %%
tmpdf = df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df[df.TotalCharges.isna()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# ...

# %%
df[df['Churn']=='No'].groupby('tenure')['Churn'].count().sort_values()[:20]
# Out:
# tenure
# 0     11
# 36    40
# 39    42
# 28    45
# 44    45
# 38    46
# 21    46
# 31    49
# 43    50
# 33    50
# 32    50
# 37    50
# 49    51
# 42    51
# 40    51
# 59    52
# 14    52
# 16    52
# 20    53
# 34    53
# Name: Churn, dtype: int64

# %%
df.tenure.value_counts().sort_index(ascending=False)
# Out:
# 72    362
# 71    170
# 70    119
# 69     95
# 68    100
#      ...
# 4     176
# 3     200
# 2     238
# 1     613
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df['years'] = pd.cut(x=df['tenure'], bins=[-1,12,24,36,48,60,72], labels=[1,2,3,4,5,6])

# %% [markdown]
# cutting the values of the monthly charges using the quartiles 25,50,75,100

# %%
df['MchargesBins'] = pd.cut(x=df['MonthlyCharges'], bins=[-1,50,80,100,120], labels=[1,2,3,4])

# %%
df['TechSupport'].value_counts()
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %%
df['InternetService'] = df['InternetService'].map({'No':0, 'DSL':1, 'Fiber optic':2}).astype('int')

# %%
df['PhoneService'] = df['PhoneService'].map({'No':0, 'Yes':1}).astype('int')

# %%
df['MultipleLines'] = df['MultipleLines'].map({'No phone service':0, 'No':1, 'Yes':2}).astype('int')

# %%
df['OnlineSecurity'] = df['OnlineSecurity'].map({'No internet service':0, 'No':1, 'Yes':2}).astype('int')

# %%
df['OnlineBackup'] = df['OnlineBackup'].map({'No internet service':0, 'No':1, 'Yes':2}).astype('int')

# %%
df['DeviceProtection'] = df['DeviceProtection'].map({'No internet service':0, 'No':1, 'Yes':2}).astype('int')

# %%
df['TechSupport'] = df['TechSupport'].map({'No internet service':0, 'No':1, 'Yes':2}).astype('int')

# %%
df['StreamingTV'] = df['StreamingTV'].map({'No internet service':0, 'No':1, 'Yes':2}).astype('int')

# %%
df['StreamingMovies'] = df['StreamingMovies'].map({'No internet service':0, 'No':1, 'Yes':2}).astype('int')

# %%
df['Contract'] = df['Contract'].map({'Month-to-month':1, 'One year':2, 'Two year':3}).astype('int')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0                0              0                1               1
# ...

# %%
col_list = ['PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport',
            'StreamingTV','StreamingMovies','Contract','years','MchargesBins']

# %%
sums = []
for index, row in df.iterrows():
    sum = 0
    for col in col_list:
        sum += row[col]
    sums.append(sum)

# %%
df['Customer_value'] = sums
df['Customer_value'].value_counts().sort_values()
# Out:
# 30     85
# 29    113
# 9     115
# 8     141
# 6     159
# 7     178
# 10    199
# 26    202
# 28    204
# 11    214
# 27    229
# 25    235
# 13    263
# 22    296
# 24    298
# 23    307
# 21    329
# 16    334
# 20    349
# 14    354
# 5     365
# 12    368
# 19    387
# 18    422
# 17    434
# 15    463
# Name: Customer_value, dtype: int64

# %%
# get a good result but need better
df['Segment'] = pd.cut(x=df['Customer_value'], bins=[0,12,23,27,31], labels=['Bronze', 'Silver', 'Gold', 'premium'])

# %%
df['Segment'] = pd.cut(x=df['Customer_value'], bins=[0,18,24,27,31], labels=['Bronze', 'Silver', 'Gold', 'premium'])

# %%
for seg_value in ['Bronze', 'Silver', 'Gold', 'premium']:
    print(seg_value)
    print(df[df.Segment==seg_value]['Churn'].value_counts(normalize=True))
# Out:
# Bronze
# No     0.696932
# Yes    0.303068
# Name: Churn, dtype: float64
# Silver
# No     0.735504
# Yes    0.264496
# Name: Churn, dtype: float64
# Gold
# No     0.84985
# Yes    0.15015
# Name: Churn, dtype: float64
# premium
# No     0.915423
# Yes    0.084577
# Name: Churn, dtype: float64

# %%
tmpdf['Segment'] = df['Segment']

# %%
df[df.Segment=='premium']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# 28    5248-YGIJN    Male              0     Yes         No      72
# 57    5067-XJQFU    Male              1     Yes        Yes      66
# 59    5954-BDFSG  Female              0      No         No      72
# ...          ...     ...            ...     ...        ...     ...
# 6913  8213-TAZPM  Female              0     Yes        Yes      69
# 6934  6257-DTAYD    Male              0     Yes         No      71
# 6935  4616-ULAOA  Female              0     Yes        Yes      65
# 7002  9586-JGQKH  Female              0     Yes         No      64
# 7042  3186-AJIEK    Male              0      No         No      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 15               1              2                2               2
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='PaymentMethod', hue='Segment')
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='Partner', hue='Segment')
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='Dependents', hue='Segment')
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='MultipleLines', hue='Segment')
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
df[df.MultipleLines==2]['Churn'].value_counts()
# Out:
# No     2121
# Yes     850
# Name: Churn, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='PaperlessBilling', hue='Segment')
# Out:
# <AxesSubplot:xlabel='PaperlessBilling', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='Contract', hue='Segment')
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='InternetService', hue='Segment')
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
churn_df = df[df.Churn=='Yes']
Not_churn_df = df[df.Churn=='No']

# %%
sns.countplot(data=churn_df, x='Contract', hue='Segment')
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
sns.countplot(data=churn_df, x='MultipleLines', hue='Segment')
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
# how does internet service and how it affects churn rates
sns.histplot(churn_df[churn_df.InternetService==2]['TotalCharges'])
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Count'>

# %%
sns.countplot(data=churn_df, x='InternetService', hue='Segment')
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
sns.histplot(churn_df[churn_df['InternetService']==2]['MonthlyCharges'])
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Count'>

# %%
# so they pay so much money for just one service and they don't get any other services
# we can make offers to make them pay the same amount for more services
churn_df[churn_df['InternetService']==2]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# ...          ...     ...            ...     ...        ...     ...
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 4                1              1                2               1
# ...

# %%
z = df.groupby(['Segment','Churn'])['MonthlyCharges'].agg({'mean', 'count'}).reset_index()

# %%
z
# Out:
#    Segment Churn  count        mean
# 0   Bronze    No   2794   39.444971
# 1   Bronze   Yes   1215   63.246502
# 2   Silver    No   1446   78.967635
# 3   Silver   Yes    520   92.789423
# 4     Gold    No    566   94.533392
# 5     Gold   Yes    100  103.122500
# 6  premium    No    368  106.204891
# 7  premium   Yes     34  109.517647

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=z, x='Segment', y='mean', hue='Churn')
plt.title('mean Monthly Charges per Segment')
plt.ylabel('mean Monthly Charges')
plt.xlabel('Year');

# %%
churn_df.groupby('InternetService')['MonthlyCharges'].mean()
# Out:
# InternetService
# 0    20.368142
# 1    49.083224
# 2    88.126484
# Name: MonthlyCharges, dtype: float64

# %%
churn_df.groupby('Segment')['MonthlyCharges'].mean()
# Out:
# Segment
# Bronze      63.246502
# Silver      92.789423
# Gold       103.122500
# premium    109.517647
# Name: MonthlyCharges, dtype: float64

# %%
Not_churn_df.groupby('Segment')['MonthlyCharges'].mean()
# Out:
# Segment
# Bronze      39.444971
# Silver      78.967635
# Gold        94.533392
# premium    106.204891
# Name: MonthlyCharges, dtype: float64

# %%
l = ['MultipleLines','InternetService','OnlineSecurity','OnlineBackup',	'DeviceProtection',	'TechSupport',	'StreamingTV',	'StreamingMovies'	,'Contract', 'Churn']
for v in l:
    sns.countplot(data=tmpdf, x=v, hue='Segment')
    plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=tmpdf, x='Contract', hue='Churn')
plt.title('Churn rate per Contract')
plt.ylabel('Customer Count')
plt.xlabel('Contract type');

# %%
df[(df.Segment=='Bronze') & (df.Churn=='Yes')]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 20    8779-QRDMV    Male              1      No         No       1
# 22    1066-JKSGK    Male              0      No         No       1
# ...          ...     ...            ...     ...        ...     ...
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 2                1              1                1               2
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=tmpdf[(df.Segment=='Bronze') & (df.InternetService!=0)], x='InternetService', hue='Churn')
plt.title('Churn rate per Internet Service')
plt.ylabel('Customer Count')
plt.xlabel('Internet Service');

# %%
df[(df.Segment=='Bronze') & (df.Churn=='Yes')]['InternetService'].value_counts()
# Out:
# 2    700
# 1    402
# 0    113
# Name: InternetService, dtype: int64

# %%
df[(df.Segment=='Bronze') & (df.Churn=='No')]['InternetService'].value_counts()
# Out:
# 0    1413
# 1     960
# 2     421
# Name: InternetService, dtype: int64

# %%
df['years']
# Out:
# 0       1
# 1       3
# 2       1
# 3       4
# 4       1
#        ..
# 7038    2
# 7039    6
# 7040    1
# 7041    1
# 7042    6
# Name: years, Length: 7043, dtype: category
# Categories (6, int64): [1 < 2 < 3 < 4 < 5 < 6]

# %%
df['current_year'] = np.ones((df.shape[0],1))*2023
df['years'] = df['years'].astype('int')
df['current_year'] = df['current_year'].astype('int')
df['customer_first_year'] = df['current_year'] - df['years']

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0                0              0                1               1
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='customer_first_year', hue='Churn')
plt.title('Churn rate for Customer per year')
plt.ylabel('Customer Count per year')
plt.xlabel('Year');

# %%
d = df[df.years==1].groupby('tenure')['Churn'].count().sort_values()
plt.figure(figsize=(10,8))
plt.xticks(np.arange(1,13))
plt.bar(x=d.index[1:], height=d.values[1:])
plt.title('Churn rate since customer first subscribe')
plt.xlabel('Customer first subscribe')
plt.ylabel('Churn rate');

# %%
sns.countplot(data=tmpdf[tmpdf.Churn=='Yes'], x='MultipleLines', hue='Segment')
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
sns.countplot(data=tmpdf[tmpdf.Churn=='No'], x='MultipleLines', hue='Segment')
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
sns.countplot(data=tmpdf, x='PhoneService', hue='Churn')
# Out:
# <AxesSubplot:xlabel='PhoneService', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=tmpdf[tmpdf.Churn=='Yes'], x='PaymentMethod', hue='Segment');

# %%
sns.countplot(data=tmpdf, x='SeniorCitizen', hue='Segment');

# %%
tmpdf[tmpdf['SeniorCitizen']==1]['Segment'].value_counts()
# Out:
# Bronze     509
# Silver     433
# Gold       129
# premium     71
# Name: Segment, dtype: int64

# %%
tmpdf[tmpdf['SeniorCitizen']==0]['Segment'].value_counts()
# Out:
# Bronze     3500
# Silver     1533
# Gold        537
# premium     331
# Name: Segment, dtype: int64

# %%
sns.countplot(data=tmpdf, x='MultipleLines', hue='Segment')
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
cols = ['gender', 'SeniorCitizen', 'Partner','Dependents','tenure','PhoneService','MultipleLines','InternetService',
        'OnlineSecurity', 'DeviceProtection','TechSupport','StreamingTV', 'StreamingMovies', 'Contract','PaperlessBilling', 'PaymentMethod',
        'MonthlyCharges', 'TotalCharges']

# %%
tmpdf['TotalCharges'] = tmpdf['TotalCharges'].fillna(tmpdf.TotalCharges.mean())
tmpdf['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
train_df = pd.get_dummies(tmpdf[cols])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
y = tmpdf['Churn'].map({'Yes':1, 'No':0})

# %%
x_train, x_test, y_train, y_test = train_test_split(train_df,y,test_size=0.2, stratify=y, random_state=42)

# %%
s = StandardScaler()
x_train = s.fit_transform(x_train)
x_test = s.transform(x_test)

# %%
x_train
# Out:
# array([[-0.44177295,  0.10237124, -0.52197565, ..., -0.52380561,
#          1.40690298, -0.54384572],
#        [-0.44177295, -0.71174346,  0.33747781, ..., -0.52380561,
#         -0.71078107,  1.83875676],
#        [-0.44177295, -0.79315493, -0.80901319, ..., -0.52380561,
#         -0.71078107,  1.83875676],
#        ...,
#        [ 2.2636062 , -0.30468611,  1.25666162, ..., -0.52380561,
#         -0.71078107,  1.83875676],
#        [-0.44177295, -0.34539184, -1.47766135, ...,  1.90910518,
#         -0.71078107, -0.54384572],
#        [-0.44177295, -1.07809507, -1.46936546, ..., -0.52380561,
#         -0.71078107,  1.83875676]])

# %%
clf = RandomForestClassifier()
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
roc_auc_score(y_train,clf.predict(x_train))
# Out:
# 0.9970548522456671

# %%
roc_auc_score(y_test,clf.predict(x_test))
# Out:
# 0.6885013821075202

# %%
clf.feature_importances_
# Out:
# array([0.01984387, 0.13763959, 0.14884655, 0.17115559, 0.01827581,
#        0.01800351, 0.01473705, 0.01521117, 0.01201264, 0.01237922,
#        0.00267707, 0.00321799, 0.0130464 , 0.00273206, 0.01348531,
#        0.01241716, 0.02194594, 0.00441376, 0.02662442, 0.00260676,
#        0.01170801, 0.01513887, 0.00491859, 0.01172968, 0.03031485,
#        0.00343834, 0.0110382 , 0.0109988 , 0.00160333, 0.01135788,
#        0.01131725, 0.00431266, 0.01204705, 0.0646732 , 0.00905719,
#        0.02005701, 0.01414842, 0.01649947, 0.01220832, 0.01238917,
#        0.02868778, 0.01108405])

# %%
feature_importance_df = pd.DataFrame({'feature': cols, 'importance': clf.feature_importances_})

# Sort the dataframe by importance in descending order
feature_importance_df = feature_importance_df.sort_values('importance', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\DataPreparation\Telcom_churn.ipynb Cell 86 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/f%3A/DataPreparation/Telcom_churn.ipynb#Y154sZmlsZQ%3D%3D?line=0'>1</a> feature_importance_df = pd.DataFrame({'feature': cols, 'importance': clf.feature_importances_})
#       <a href='vscode-notebook-cell:/f%3A/DataPreparation/Telcom_churn.ipynb#Y154sZmlsZQ%3D%3D?line=2'>3</a> # Sort the dataframe by importance in descending order
#       <a href='vscode-notebook-cell:/f%3A/DataPreparation/Telcom_churn.ipynb#Y154sZmlsZQ%3D%3D?line=3'>4</a> feature_importance_df = feature_importance_df.sort_values('importance', ascending=False)
#
# File c:\Users\khale\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
# ...
